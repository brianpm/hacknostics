# %%
import xarray as xr
import zarr
from pathlib import Path
from numcodecs import Blosc

# %%
def combine_zarrs_along_time(source_zarr_paths, target_zarr_dir, target_zarr_prefix, chunking=None):
    """
    Combine multiple Zarr archives along the time dimension and write to a new Zarr.
    
    Parameters:
    -----------
    source_zarr_paths : list of zarr or path to zarr
        Paths to the source Zarr archives.
    target_zarr_path : str
        Path to the output combined Zarr archive.
    chunking : dict, optional
        Chunk sizes for the output Zarr (e.g., {'time': 48, 'cell': 262144}).
    """
    if isinstance(source_zarr_paths, list):
        print(f"Opening {len(source_zarr_paths)} Zarr archives...")
        datasets = [xr.open_zarr(z) for z in source_zarr_paths]
        print("Concatenating along time...")
        combined = xr.concat(datasets, dim="time")
    elif isinstance(source_zarr_paths, Path):
        combined = xr.open_zarr(source_zarr_paths)
    else:
        raise ValueError("input needs to be list of zarrs or a path to a zarr")
    # Set up encoding for chunking
    if chunking is None:
        chunking = {"time": 36, "cell": 48}
    combined = combined.chunk(chunking)

    stime = combined.time[0].dt.strftime("%Y%m%d%H%M")
    etime = combined.time[-1].dt.strftime("%Y%m%d%H%M")
    time_label = f"{stime.item()}-{etime.item()}"

    tgt_zarr = target_zarr_dir / f"{target_zarr_prefix}_{time_label}.zarr"

    encoding = {}
    for var in combined.data_vars:
        # Get the chunks as a flat tuple
        var_chunks = tuple(x[0] if isinstance(x, tuple) else x 
                         for x in combined[var].chunks)
        encoding[var] = {
            "chunks": var_chunks,
            "compressor": Blosc(cname='zstd', clevel=3, shuffle=2)
        }
    
    print(f"Writing combined dataset to {tgt_zarr} ...")
    combined.to_zarr(tgt_zarr, 
                     mode="w", 
                     zarr_format=2, 
                     consolidated=True, 
                     encoding=encoding,
                     compute=True
                     )
    print("Done.")

# Example usage:
# source_zarrs = ["file1.zarr", "file2.zarr", "file3.zarr"]
# combine_zarrs_along_time(source_zarrs, "combined.zarr", chunking={'time': 48, 'cell': 262144})

# %%
# src_loc = Path("/glade/derecho/scratch/digital-earths-hackathon/mpas_DYAMOND3/30min")
# src_zarr = sorted(src_loc.glob("DYAMOND_diag_30min_to_hp1.zarr"))

# tgt_zarr_loc = Path("/glade/campaign/cgd/cas/brianpm/hack25/rechunk")
# tgt_zarr_prefix = "DYAMOND_diag_30min_to_hp1"


# DYAMOND2 15min
src_loc = Path("/glade/derecho/scratch/digital-earths-hackathon/mpas_DYAMOND2/15min")
# src_zarr = sorted(src_loc.glob("DYAMOND2_diag_15min_to_hp1.zarr"))
src_zarr = src_loc / "DYAMOND2_diag_15min_to_hp1.zarr"

tgt_zarr_loc = Path("/glade/campaign/cgd/cas/brianpm/hack25/rechunk")
tgt_zarr_prefix = "DYAMOND2_diag_15min_to_hp1"

ochunks = {'time':96, 'cell':48}
combine_zarrs_along_time(src_zarr, tgt_zarr_loc, tgt_zarr_prefix, chunking=ochunks)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:539, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     538 try:
# --> 539     dates = _decode_datetime_with_pandas(
#     540         flat_num_dates, units, calendar, time_unit
#     541     )
#     542 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:455, in _decode_datetime_with_pandas(flat_num_dates, units, calendar, time_resolution)
#     454 if not _is_standard_calendar(calendar):
# --> 455     raise OutOfBoundsDatetime(
#     456         f"Cannot decode times from a non-standard calendar, {calendar!r}, using "
#     457         "pandas."
#     458     )
#     460 # Work around pandas.to_timedelta issue with dtypes smaller than int64 and
#     461 # NumPy 2.0 by casting all int and uint data to int64 and uint64,
#     462 # respectively. See https://github.com/pandas-dev/pandas/issues/56996 for
#     463 # more details.
#
# OutOfBoundsDatetime: Cannot decode times from a non-standard calendar, 'time_calendar', using pandas.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:330, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     329 try:
# --> 330     result = decode_cf_datetime(
#     331         example_value, units, calendar, use_cftime, time_unit
#     332     )
#     333 except Exception as err:
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:543, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     542 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
# --> 543     dates = _decode_datetime_with_cftime(
#     544         flat_num_dates.astype(float), units, calendar
#     545     )
#     546     # retrieve cftype
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:358, in _decode_datetime_with_cftime(num_dates, units, calendar)
#     356 if num_dates.size > 0:
#     357     return np.asarray(
# --> 358         cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#     359     )
#     360 else:
#
# File src/cftime/_cftime.pyx:587, in cftime._cftime.num2date()
#
# File src/cftime/_cftime.pyx:123, in cftime._cftime._dateparse()
#
# File src/cftime/_cftime.pyx:1194, in cftime._cftime.datetime.__init__()
#
# ValueError: calendar must be one of ['standard', 'gregorian', 'proleptic_gregorian', 'noleap', 'julian', 'all_leap', '365_day', '366_day', '360_day'], got 'time_calendar'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:405, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     404 try:
# --> 405     new_vars[k] = decode_cf_variable(
#     406         k,
#     407         v,
#     408         concat_characters=_item_or_default(concat_characters, k, True),
#     409         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     410         decode_times=_item_or_default(decode_times, k, True),
#     411         stack_char_dim=stack_char_dim,
#     412         use_cftime=_item_or_default(use_cftime, k, None),
#     413         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     414     )
#     415 except Exception as e:
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:238, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     229             raise TypeError(
#     230                 "Usage of 'use_cftime' as a kwarg is not allowed "
#     231                 "if a 'CFDatetimeCoder' instance is passed to "
#    (...)    236                 "    ds = xr.open_dataset(decode_times=time_coder)\n",
#     237             )
# --> 238     var = decode_times.decode(var, name=name)
#     240 if decode_endianness and not var.dtype.isnative:
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:1380, in CFDatetimeCoder.decode(self, variable, name)
#    1379 calendar = pop_to(attrs, encoding, "calendar")
# -> 1380 dtype = _decode_cf_datetime_dtype(
#    1381     data, units, calendar, self.use_cftime, self.time_unit
#    1382 )
#    1383 transform = partial(
#    1384     decode_cf_datetime,
#    1385     units=units,
#    (...)   1388     time_unit=self.time_unit,
#    1389 )
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:342, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     337     msg = (
#     338         f"unable to decode time units {units!r} with {calendar_msg!r}. Try "
#     339         "opening your dataset with decode_times=False or installing cftime "
#     340         "if it is not installed."
#     341     )
# --> 342     raise ValueError(msg) from err
#     343 else:
#
# ValueError: unable to decode time units 'hours since 2000-01-01 00:00:00' with "calendar 'time_calendar'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 17
#      14 tgt_zarr_prefix = "DYAMOND2_diag_15min_to_hp1"
#      16 ochunks = {'time':96, 'cell':48}
# ---> 17 combine_zarrs_along_time(src_zarr, tgt_zarr_loc, tgt_zarr_prefix, chunking=ochunks)
#
# Cell In[2], line 20, in combine_zarrs_along_time(source_zarr_paths, target_zarr_dir, target_zarr_prefix, chunking)
#      18     combined = xr.concat(datasets, dim="time")
#      19 elif isinstance(source_zarr_paths, Path):
# ---> 20     combined = xr.open_zarr(source_zarr_paths)
#      21 else:
#      22     raise ValueError("input needs to be list of zarrs or a path to a zarr")
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/backends/zarr.py:1535, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1521     raise TypeError(
#    1522         "open_zarr() got unexpected keyword arguments " + ",".join(kwargs.keys())
#    1523     )
#    1525 backend_kwargs = {
#    1526     "synchronizer": synchronizer,
#    1527     "consolidated": consolidated,
#    (...)   1532     "zarr_format": zarr_format,
#    1533 }
# -> 1535 ds = open_dataset(
#    1536     filename_or_obj=store,
#    1537     group=group,
#    1538     decode_cf=decode_cf,
#    1539     mask_and_scale=mask_and_scale,
#    1540     decode_times=decode_times,
#    1541     concat_characters=concat_characters,
#    1542     decode_coords=decode_coords,
#    1543     engine="zarr",
#    1544     chunks=chunks,
#    1545     drop_variables=drop_variables,
#    1546     chunked_array_type=chunked_array_type,
#    1547     from_array_kwargs=from_array_kwargs,
#    1548     backend_kwargs=backend_kwargs,
#    1549     decode_timedelta=decode_timedelta,
#    1550     use_cftime=use_cftime,
#    1551     zarr_version=zarr_version,
#    1552     use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#    1553 )
#    1554 return ds
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)    705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/backends/zarr.py:1625, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1623 store_entrypoint = StoreBackendEntrypoint()
#    1624 with close_on_error(store):
# -> 1625     ds = store_entrypoint.open_dataset(
#    1626         store,
#    1627         mask_and_scale=mask_and_scale,
#    1628         decode_times=decode_times,
#    1629         concat_characters=concat_characters,
#    1630         decode_coords=decode_coords,
#    1631         drop_variables=drop_variables,
#    1632         use_cftime=use_cftime,
#    1633         decode_timedelta=decode_timedelta,
#    1634     )
#    1635 return ds
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/backends/store.py:47, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      44 vars, attrs = filename_or_obj.load()
#      45 encoding = filename_or_obj.get_encoding()
# ---> 47 vars, attrs, coord_names = conventions.decode_cf_variables(
#      48     vars,
#      49     attrs,
#      50     mask_and_scale=mask_and_scale,
#      51     decode_times=decode_times,
#      52     concat_characters=concat_characters,
#      53     decode_coords=decode_coords,
#      54     drop_variables=drop_variables,
#      55     use_cftime=use_cftime,
#      56     decode_timedelta=decode_timedelta,
#      57 )
#      59 ds = Dataset(vars, attrs=attrs)
#      60 ds = ds.set_coords(coord_names.intersection(vars))
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:416, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     405     new_vars[k] = decode_cf_variable(
#     406         k,
#     407         v,
#    (...)    413         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     414     )
#     415 except Exception as e:
# --> 416     raise type(e)(f"Failed to decode variable {k!r}: {e}") from e
#     417 if decode_coords in [True, "coordinates", "all"]:
#     418     var_attrs = new_vars[k].attrs
#
# ValueError: Failed to decode variable 'time': unable to decode time units 'hours since 2000-01-01 00:00:00' with "calendar 'time_calendar'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.

# %%
# check input
dsi = xr.open_zarr(src_zarr, decode_times=False, )

# %%
dsi['time'].attrs['calendar'] = 'standard'
dsi['time'].attrs['units'] = 'seconds since 2000-01-01 00:00:00'

# %%
dsi['time']
# Out:
# <xarray.DataArray 'time' (time: 3937)> Size: 31kB
# array([1.579478e+18, 1.579479e+18, 1.579480e+18, ..., 1.583019e+18,
#        1.583020e+18, 1.583021e+18], shape=(3937,))
# Coordinates:
#   * time     (time) float64 31kB 1.579e+18 1.579e+18 ... 1.583e+18 1.583e+18
# Attributes:
#     long_name:  valid time
#     calendar:   standard
#     units:      hours since 2000-01-01 00:00:00

# %%
dsi = xr.decode_cf(dsi)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File timedeltas.pyx:1682, in pandas._libs.tslibs.timedeltas._Timedelta._as_creso()
#
# File np_datetime.pyx:683, in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: result would overflow
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsTimedelta                      Traceback (most recent call last)
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:539, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     538 try:
# --> 539     dates = _decode_datetime_with_pandas(
#     540         flat_num_dates, units, calendar, time_unit
#     541     )
#     542 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:485, in _decode_datetime_with_pandas(flat_num_dates, units, calendar, time_resolution)
#     483 if flat_num_dates.size > 0:
#     484     # avoid size 0 datetimes GH1329
# --> 485     _check_date_for_units_since_refdate(
#     486         flat_num_dates.min(), time_unit, ref_date
#     487     )
#     488     _check_date_for_units_since_refdate(
#     489         flat_num_dates.max(), time_unit, ref_date
#     490     )
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:381, in _check_date_for_units_since_refdate(date, unit, ref_date)
#     379     # this will raise on overflow if ref_date + delta
#     380     # can't be represented in the current ref_date resolution
# --> 381     return timestamp_as_unit(ref_date + delta, ref_date.unit)
#     382 else:
#     383     # if date is exactly NaT (np.iinfo("int64").min) return NaT
#     384     # to make follow-up checks work
#
# File timestamps.pyx:446, in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# File timedeltas.pyx:1685, in pandas._libs.tslibs.timedeltas._Timedelta._as_creso()
#
# OutOfBoundsTimedelta: Cannot cast 18281000000000 days 00:00:00 to unit='ns' without overflow.
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:330, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     329 try:
# --> 330     result = decode_cf_datetime(
#     331         example_value, units, calendar, use_cftime, time_unit
#     332     )
#     333 except Exception as err:
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:543, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     542 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
# --> 543     dates = _decode_datetime_with_cftime(
#     544         flat_num_dates.astype(float), units, calendar
#     545     )
#     546     # retrieve cftype
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:358, in _decode_datetime_with_cftime(num_dates, units, calendar)
#     356 if num_dates.size > 0:
#     357     return np.asarray(
# --> 358         cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#     359     )
#     360 else:
#
# File src/cftime/_cftime.pyx:627, in cftime._cftime.num2date()
#
# File src/cftime/_cftime.pyx:421, in cftime._cftime.cast_to_int()
#
# OverflowError: time values outside range of 64 bit signed integers
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:405, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     404 try:
# --> 405     new_vars[k] = decode_cf_variable(
#     406         k,
#     407         v,
#     408         concat_characters=_item_or_default(concat_characters, k, True),
#     409         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     410         decode_times=_item_or_default(decode_times, k, True),
#     411         stack_char_dim=stack_char_dim,
#     412         use_cftime=_item_or_default(use_cftime, k, None),
#     413         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     414     )
#     415 except Exception as e:
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:238, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     229             raise TypeError(
#     230                 "Usage of 'use_cftime' as a kwarg is not allowed "
#     231                 "if a 'CFDatetimeCoder' instance is passed to "
#    (...)    236                 "    ds = xr.open_dataset(decode_times=time_coder)\n",
#     237             )
# --> 238     var = decode_times.decode(var, name=name)
#     240 if decode_endianness and not var.dtype.isnative:
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:1380, in CFDatetimeCoder.decode(self, variable, name)
#    1379 calendar = pop_to(attrs, encoding, "calendar")
# -> 1380 dtype = _decode_cf_datetime_dtype(
#    1381     data, units, calendar, self.use_cftime, self.time_unit
#    1382 )
#    1383 transform = partial(
#    1384     decode_cf_datetime,
#    1385     units=units,
#    (...)   1388     time_unit=self.time_unit,
#    1389 )
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/coding/times.py:342, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     337     msg = (
#     338         f"unable to decode time units {units!r} with {calendar_msg!r}. Try "
#     339         "opening your dataset with decode_times=False or installing cftime "
#     340         "if it is not installed."
#     341     )
# --> 342     raise ValueError(msg) from err
#     343 else:
#
# ValueError: unable to decode time units 'seconds since 2000-01-01 00:00:00' with "calendar 'standard'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dsi = xr.decode_cf(dsi)
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:577, in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     574 else:
#     575     raise TypeError("can only decode Dataset or DataStore objects")
# --> 577 vars, attrs, coord_names = decode_cf_variables(
#     578     vars,
#     579     attrs,
#     580     concat_characters,
#     581     mask_and_scale,
#     582     decode_times,
#     583     decode_coords,
#     584     drop_variables=drop_variables,
#     585     use_cftime=use_cftime,
#     586     decode_timedelta=decode_timedelta,
#     587 )
#     588 ds = Dataset(vars, attrs=attrs)
#     589 ds = ds.set_coords(coord_names.union(extra_coords).intersection(vars))
#
# File ~/miniconda3/envs/chunky/lib/python3.13/site-packages/xarray/conventions.py:416, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     405     new_vars[k] = decode_cf_variable(
#     406         k,
#     407         v,
#    (...)    413         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     414     )
#     415 except Exception as e:
# --> 416     raise type(e)(f"Failed to decode variable {k!r}: {e}") from e
#     417 if decode_coords in [True, "coordinates", "all"]:
#     418     var_attrs = new_vars[k].attrs
#
# ValueError: Failed to decode variable 'time': unable to decode time units 'seconds since 2000-01-01 00:00:00' with "calendar 'standard'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.

# %%
# Check on the output:
# dso = xr.open_zarr("/glade/campaign/cgd/cas/brianpm/hack25/rechunk/DYAMOND_diag_30min_to_hp1_202001200000-202002132330.zarr")

# %%
dso['cape'].compute()
# Out:
# <xarray.DataArray 'cape' (time: 1200, cell: 48)> Size: 230kB
# array([[1.1503353e+01, 5.6476556e-02, 2.2601113e+00, ..., 6.8291779e+01,
#         2.8565771e+02, 7.9549390e+02],
#        [1.5402848e+01, 1.7547055e-01, 5.0487623e+00, ..., 8.7394890e+01,
#         2.8526184e+02, 8.0344836e+02],
#        [1.5975126e+01, 2.7778405e-01, 6.0990009e+00, ..., 9.3648903e+01,
#         2.8831238e+02, 8.0088776e+02],
#        ...,
#        [8.2282753e+01, 3.2590153e+00, 1.2135754e+01, ..., 2.0392427e+02,
#         1.1396028e+02, 9.6802777e+02],
#        [8.2082031e+01, 3.0804992e+00, 1.2113480e+01, ..., 2.0080893e+02,
#         1.0595895e+02, 9.4757434e+02],
#        [8.1748802e+01, 2.8972819e+00, 1.2057562e+01, ..., 1.9831219e+02,
#         9.9871635e+01, 9.3310254e+02]], shape=(1200, 48), dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 10kB 2020-01-20 ... 2020-02-13T23:30:00
# Dimensions without coordinates: cell
# Attributes:
#     long_name:  Convective available potential energy
#     units:      J kg^{-1}

# %%
time_label
# Out:
# '202001200000-202001240900'

# %%
tgt_zarr = Path("/glade/campaign/cgd/cas/brianpm/hack25/rechunk")

# Save the combined dataset to a new Zarr archive
combined_ds.to_zarr(tgt_zarr / f'DYAMOND_diag_3h_{time_label}_to_hp1.zarr', zarr_format=2)
# Out:
# /glade/derecho/scratch/brianpm/tmp/ipykernel_52957/2121708585.py:4: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 2020-01-20'. Serializing with units 'hours since 2020-01-20' instead. Set encoding['dtype'] to floating point dtype to serialize with units 'days since 2020-01-20'. Set encoding['units'] to 'hours since 2020-01-20' to silence this warning .
#   combined_ds.to_zarr(tgt_zarr / f'DYAMOND_diag_3h_{time_label}_to_hp1.zarr')
# /glade/u/home/brianpm/miniconda3/envs/p12/lib/python3.12/site-packages/zarr/api/asynchronous.py:205: UserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
ds = xr.open_mfdataset("/glade/campaign/mmm/wmr/fjudt/projects/dyamond_2/3.75km/history.2020-*.nc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 ds = xr.open_mfdataset("/glade/campaign/mmm/wmr/fjudt/projects/dyamond_2/3.75km/history.2020-*.nc")
#
# File ~/miniconda3/envs/p12/lib/python3.12/site-packages/xarray/backends/api.py:1663, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1650     combined = _nested_combine(
#    1651         datasets,
#    1652         concat_dims=concat_dim,
#    (...)   1658         combine_attrs=combine_attrs,
#    1659     )
#    1660 elif combine == "by_coords":
#    1661     # Redo ordering from coordinates, ignoring how they were ordered
#    1662     # previously
# -> 1663     combined = combine_by_coords(
#    1664         datasets,
#    1665         compat=compat,
#    1666         data_vars=data_vars,
#    1667         coords=coords,
#    1668         join=join,
#    1669         combine_attrs=combine_attrs,
#    1670     )
#    1671 else:
#    1672     raise ValueError(
#    1673         f"{combine} is an invalid option for the keyword argument ``combine``"
#    1674     )
#
# File ~/miniconda3/envs/p12/lib/python3.12/site-packages/xarray/structure/combine.py:983, in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs)
#     979     grouped_by_vars = groupby_defaultdict(data_objects, key=vars_as_keys)
#     981     # Perform the multidimensional combine on each group of data variables
#     982     # before merging back together
# --> 983     concatenated_grouped_by_data_vars = tuple(
#     984         _combine_single_variable_hypercube(
#     985             tuple(datasets_with_same_vars),
#     986             fill_value=fill_value,
#     987             data_vars=data_vars,
#     988             coords=coords,
#     989             compat=compat,
#     990             join=join,
#     991             combine_attrs=combine_attrs,
#     992         )
#     993         for vars, datasets_with_same_vars in grouped_by_vars
#     994     )
#     996 return merge(
#     997     concatenated_grouped_by_data_vars,
#     998     compat=compat,
#    (...)   1001     combine_attrs=combine_attrs,
#    1002 )
#
# File ~/miniconda3/envs/p12/lib/python3.12/site-packages/xarray/structure/combine.py:984, in <genexpr>(.0)
#     979     grouped_by_vars = groupby_defaultdict(data_objects, key=vars_as_keys)
#     981     # Perform the multidimensional combine on each group of data variables
#     982     # before merging back together
#     983     concatenated_grouped_by_data_vars = tuple(
# --> 984         _combine_single_variable_hypercube(
#     985             tuple(datasets_with_same_vars),
#     986             fill_value=fill_value,
#     987             data_vars=data_vars,
#     988             coords=coords,
#     989             compat=compat,
#     990             join=join,
#     991             combine_attrs=combine_attrs,
#     992         )
#     993         for vars, datasets_with_same_vars in grouped_by_vars
#     994     )
#     996 return merge(
#     997     concatenated_grouped_by_data_vars,
#     998     compat=compat,
#    (...)   1001     combine_attrs=combine_attrs,
#    1002 )
#
# File ~/miniconda3/envs/p12/lib/python3.12/site-packages/xarray/structure/combine.py:645, in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     639 if len(datasets) == 0:
#     640     raise ValueError(
#     641         "At least one Dataset is required to resolve variable names "
#     642         "for combined hypercube."
#     643     )
# --> 645 combined_ids, concat_dims = _infer_concat_order_from_coords(list(datasets))
#     647 if fill_value is None:
#     648     # check that datasets form complete hypercube
#     649     _check_shape_tile_ids(combined_ids)
#
# File ~/miniconda3/envs/p12/lib/python3.12/site-packages/xarray/structure/combine.py:158, in _infer_concat_order_from_coords(datasets)
#     152             tile_ids = [
#     153                 tile_id + (position,)
#     154                 for tile_id, position in zip(tile_ids, order, strict=True)
#     155             ]
#     157 if len(datasets) > 1 and not concat_dims:
# --> 158     raise ValueError(
#     159         "Could not find any dimension coordinates to use to "
#     160         "order the datasets for concatenation"
#     161     )
#     163 combined_ids = dict(zip(tile_ids, datasets, strict=True))
#     165 return combined_ids, concat_dims
#
# ValueError: Could not find any dimension coordinates to use to order the datasets for concatenation
