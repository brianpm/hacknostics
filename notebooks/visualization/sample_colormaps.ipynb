# %%
import geocat.viz as gv # .cmaps as gvcmaps
cmap = gv.cmaps.WhiteBlueGreenYellowRed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import geocat.viz as gv # .cmaps as gvcmaps
# ----> 2 cmap = gv.cmaps.WhiteBlueGreenYellowRed
#
# AttributeError: module 'geocat.viz' has no attribute 'cmaps'

# %%
import cmaps

cmap = cmaps.WhiteBlueGreenYellowRed
# Use directly with matplotlib/xarray plots:
# da.plot(cmap=cmap)

# %%
cmap
