# %% [markdown]
# # Downloading
#
# There are many options for downloading files from a python script. In my experience, the easiest is to just use `wget`. The `wget` python package needs to be installed in the environment (https://pypi.org/project/wget/). _I believe this needs to be installed like `conda install python-wget`_.

# %%
import wget
from pathlib import Path


#
# fils --- list of file URLs. This example uses a temporary set of files via the CERES ordering tool. 
#
fils = ['https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202103-202103.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202111-202111.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202107-202107.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202105-202105.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202106-202106.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202108-202108.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202110-202110.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202109-202109.nc',
        'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21814/dir1/CERES_EBAF-TOA_Ed4.1_Subset_202104-202104.nc']

v = Path("/Volumes/Drudonna/CERES/monthly_files/download")
for f in fils:
    dname = f.split('/')
    dest = v / dname[-1]
    print(dest)
    wget.download(f, str(dest))
# Out:
# /Volumes/Drudonna/CERES/monthly_files/download/CERES_EBAF-TOA_Ed4.1_Subset_202103-202103.nc
# 100% [..........................................................................] 1419775 / 1419775/Volumes/Drudonna/CERES/monthly_files/download/CERES_EBAF-TOA_Ed4.1_Subset_202111-202111.nc
# 100% [..........................................................................] 1381524 / 1381524/Volumes/Drudonna/CERES/monthly_files/download/CERES_EBAF-TOA_Ed4.1_Subset_202107-202107.nc
# 100% [..........................................................................] 1380328 / 1380328/Volumes/Drudonna/CERES/monthly_files/download/CERES_EBAF-TOA_Ed4.1_Subset_202105-202105.nc
# 100% [..........................................................................] 1386067 / 1386067/Volumes/Drudonna/CERES/monthly_files/download/CERES_EBAF-TOA_Ed4.1_Subset_202106-202106.nc
# ...

# %%
fils = ['https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201605-201605.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201312-201312.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200808-200808.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201711-201711.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200802-200802.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201211-201211.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201207-201207.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_202103-202103.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200110-200110.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201511-201511.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201105-201105.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201501-201501.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200904-200904.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200712-200712.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201005-201005.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200303-200303.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200310-200310.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201905-201905.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201508-201508.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201705-201705.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200906-200906.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200602-200602.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201410-201410.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200108-200108.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201007-201007.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200812-200812.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201602-201602.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201807-201807.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200408-200408.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201406-201406.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201305-201305.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200012-200012.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201912-201912.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201003-201003.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201108-201108.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200201-200201.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201206-201206.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_202105-202105.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200605-200605.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201606-201606.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201603-201603.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200302-200302.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200806-200806.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201908-201908.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200609-200609.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200210-200210.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200406-200406.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_202004-202004.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200004-200004.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201910-201910.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_
nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_202012-202012.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200407-200407.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200708-200708.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200301-200301.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200205-200205.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_201102-201102.nc',
'https://ceres-tool.larc.nasa.gov/ord-tool/data1//CERES_2022-02-08:21816/dir1/CERES_EBAF_Ed4.1_Subset_200008-200008.nc']

# %%
#
# A better version -- Check whether the file exists before downloading, SKIP it if so
#

v = Path("/Volumes/Drudonna/CERES/monthly_files/download")
final_dst = Path("/Volumes/Drudonna/CERES/monthly_files/")
download_count = 0
for f in fils:
    dname = f.split('/')
    dest = v / dname[-1]
    if (final_dst / dname[-1]).is_file():
        print(f"File {dname[-1]} exists, so skipping.")
    else:
        print(f"Download: {dest}")
        download_count += 1 
        wget.download(f, str(dest))
    
print(download_count)
# Out:
# File CERES_EBAF_Ed4.1_Subset_201605-201605.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201312-201312.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_200808-200808.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201711-201711.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_200802-200802.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201211-201211.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201207-201207.nc exists, so skipping.
# Download: /Volumes/Drudonna/CERES/monthly_files/download/CERES_EBAF_Ed4.1_Subset_202103-202103.nc
# 100% [..........................................................................] 7167925 / 7167925File CERES_EBAF_Ed4.1_Subset_200110-200110.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201511-201511.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201105-201105.nc exists, so skipping.
# File CERES_EBAF_Ed4.1_Subset_201501-201501.nc exists, so skipping.
# ...

# %%
#
# These are supposed to match existing series ... the ones on /glade/work/brianpm/observations/ceres DO NOT have teh time dimension converted to unlimited.
#
import xarray as xr
ds = xr.open_dataset(final_dst / 'CERES_EBAF_Ed4.1_Subset_202104-202104.nc')
ds.data_vars
# Out:
# Data variables: (12/41)
#     toa_sw_all_mon               (time, lat, lon) float32 ...
#     toa_lw_all_mon               (time, lat, lon) float32 ...
#     toa_net_all_mon              (time, lat, lon) float32 ...
#     toa_sw_clr_c_mon             (time, lat, lon) float32 ...
#     toa_lw_clr_c_mon             (time, lat, lon) float32 ...
#     toa_net_clr_c_mon            (time, lat, lon) float32 ...
#     ...                           ...
#     sfc_net_tot_all_mon          (time, lat, lon) float32 ...
#     sfc_net_tot_clr_c_mon        (time, lat, lon) float32 ...
#     sfc_net_tot_clr_t_mon        (time, lat, lon) float32 ...
#     sfc_cre_net_sw_mon           (time, lat, lon) float32 ...
#     sfc_cre_net_lw_mon           (time, lat, lon) float32 ...
#     sfc_cre_net_tot_mon          (time, lat, lon) float32 ...
